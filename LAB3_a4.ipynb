# %%
import numpy as np 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_excel(r"C:\Users\gvsuj\Downloads\Dataset to B.tech.xlsx")
# Assuming 'df' is your DataFrame and 'label' is the name of the column to be dropped
X = df.drop(columns=['Label'])
y = df['Label']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("The X train set is :")
print(X_train.head())
print("The X test set is :")
print(X_test.head())
print("The Y train set is :")
print(y_train.head())
print("The Y test set is :")
print(y_test.head())
# Out:
# The X train set is :
#       Id                                           Judgment  \
# 687  281  "R.M. Lodha, J.\n\nLeave granted.\n\n2. The qu...
# 705  328  "CIVIL APPELLATE JURISDICTION : Civil Appeal N...
# 296   22  "Appeal by Special Leave from the Judgment and...
# 172  592  "APPELLATE JURISDICTION: Civil Appeal No. XIII...
# 863  796  1. Though this petition was listed for hearing...
#
#                                        Lawyers Summary  \
# 687  "The appellants and the respondents are kin be...
# 705                                                NaN
# 296  Shopkeeper was prosecuted for storing paddy wi...
# 172                                                NaN
# 863
#
#                                         Golden summary    Domain  \
# 687  "The case revolves around the question of whet...     Civil
# 705                                                NaN     Civil
# 296   "Appellant was tried for offences under s. 30...  Criminal
# ...
